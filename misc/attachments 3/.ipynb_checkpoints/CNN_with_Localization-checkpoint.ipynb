# %%
path = '/home/ravitha/Downloads/cat.jpg'
im_path = '/home/ravitha/D/Datasets/CBIS-DDSM Dataset/DDSM DATASET/TrainCalcfull/Calc-Training_P_00020_LEFT_MLO/08-07-2016-DDSM-49334/1-full mammogram images-93765/000000.dcm.png'

# %%
from keras.preprocessing import image
img = image.load_img(path, target_size=(224, 224))
img1 = image.load_img(im_path, target_size=(200, 200))
# Out:
# /home/ravitha/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import numpy as np
from skimage import color
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

x1 = image.img_to_array(img1)
x1 = color.rgb2gray(x1/255.)
x1 = np.expand_dims(x1, axis=0)

# %%
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.models import Model
model = ResNet50(weights='imagenet')
all_amp_layer_weights = model.layers[-1].get_weights()[0]
ResNet_model = Model(inputs=model.input, outputs=(model.layers[-4].output, model.layers[-1].output))

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 112, 112, 64) 0           bn_conv1[0][0]
# ...

# %%
model1 = ResNet50(input_shape=(200,200,1),classes = 2,weights='/home/ravitha/D/Datasets/CBIS-DDSM Dataset/DDSM DATASET/weights-improvement-23-0.84.hdf5')

all_amp_layer_weights1 = model1.layers[-1].get_weights()[0]
ResNet_model1 = Model(inputs=model1.input, outputs=(model1.layers[-4].output, model1.layers[-1].output))

# %%
model1.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            (None, 200, 200, 1)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 206, 206, 1)  0           input_5[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 100, 100, 64) 3200        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 100, 100, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 100, 100, 64) 0           bn_conv1[0][0]
# ...

# %%
print(all_amp_layer_weights1.shape)
# Out:
# (2048, 2)

# %%
print(all_amp_layer_weights.shape)
# Out:
# (2048, 1000)

# %%
all_amp_layer_weights = model.layers[-1].get_weights()
print(len(all_amp_layer_weights))
print(type(all_amp_layer_weights[0])) # Weights
print(type(all_amp_layer_weights[1])) # bias
print(all_amp_layer_weights[0].shape)
print(all_amp_layer_weights[1].shape)
# Out:
# 2
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (2048, 1000)
# (1000,)

# %%
all_amp_layer_weights = model.layers[-1].get_weights()[0]

# %%
from skimage import color

(last_conv_output1, pred_vec1) = ResNet_model1.predict(x1.reshape(1,200,200,1))
print(last_conv_output1.shape)
print(np.argmax(pred_vec1))
# Out:
# (1, 7, 7, 2048)
# 0

# %%
(last_conv_output, pred_vec) = ResNet_model.predict(x)

# %%
import scipy

last_conv_output1 = np.squeeze(last_conv_output1)
pred1 = np.argmax(pred_vec1)
mat_for_mult1 = scipy.ndimage.zoom(last_conv_output1, (32, 32, 1), order=1) 
amp_layer_weights1 = all_amp_layer_weights1[:, 1]
final_output1 = np.dot(mat_for_mult1.reshape((224*224, 2048)), amp_layer_weights1).reshape(224,224) 
final_output1 = np.resize(final_output1, (200,200))

# %%
import scipy

last_conv_output = np.squeeze(last_conv_output)
pred = np.argmax(pred_vec)
mat_for_mult = scipy.ndimage.zoom(last_conv_output, (32, 32, 1), order=1) 
amp_layer_weights = all_amp_layer_weights[:, pred]
final_output = np.dot(mat_for_mult.reshape((224*224, 2048)), amp_layer_weights).reshape(224,224)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2

im = cv2.resize(cv2.imread(im_path), (200, 200))
fig,ax = plt.subplots()
ax.imshow(im, alpha=0.5)
ax.imshow(final_output1, cmap='jet', alpha=0.5)

# %%
224*224
# Out:
# 50176
