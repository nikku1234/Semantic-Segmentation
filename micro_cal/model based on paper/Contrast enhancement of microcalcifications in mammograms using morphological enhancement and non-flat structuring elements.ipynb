# %%
from cv2 import *
import matplotlib.pyplot as plt 

IMG_SRC = 'sample/src.png'
src = imread(IMG_SRC)
plt.imshow(src)

# %%
# Kernel definition
kernel = getStructuringElement(MORPH_ELLIPSE, (5, 5))

# Contrast enhancement
dilated = dilate(src, kernel)
topHat = morphologyEx(src, MORPH_TOPHAT, kernel)
blackHat = morphologyEx(src, MORPH_BLACKHAT, kernel)
accentuated = add(src, topHat)
highContrast = subtract(accentuated, blackHat)

# Background subtraction
backgroundSubtraction = subtract(highContrast, dilated)

# Threshold to extract microcalcifications
th, thresholding = threshold(backgroundSubtraction, 25, 255, THRESH_BINARY)

plt.imshow(thresholding)

# %%
import numpy as np
print(np.shape(src))
# Out:
# (956, 694, 3)

# %%
src1 = imread('/Users/nikhil/Documents/GitHub/Semantic-Segmentation/micro_cal/inbreast/1/22427728_d713ef5849f98b6c_MG_R_ML_ANON.dcm.png',0)

# %%
plt.imshow(src1,cmap='gray')

# %%
import cv2
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(src1)
plt.imshow(cl1,cmap='gray')

# %%
print(np.shape(src1))
# Out:
# (4084, 3328)

# %%
kernel = getStructuringElement(MORPH_ELLIPSE, (2, 2))

# %%
dilated = dilate(src1, kernel)

# %%
topHat = morphologyEx(src1, MORPH_TOPHAT, kernel)

# %%
blackHat = morphologyEx(src1, MORPH_BLACKHAT, kernel)

# %%
accentuated = add(src1, topHat)

# %%
highContrast = subtract(accentuated, blackHat)

# %%
backgroundSubtraction = subtract(highContrast, dilated)

# %%
th, thresholding = threshold(backgroundSubtraction, 25, 255, THRESH_BINARY)

# %%
plt.imshow(thresholding,cmap='gray')

# %%
mask=imread('/Users/nikhil/Documents/GitHub/Semantic-Segmentation/micro_cal/inbreast/1/22427728_mask.png')

# %%
plt.imshow(mask)
